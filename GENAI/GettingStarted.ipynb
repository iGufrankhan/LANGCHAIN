# %%
import os
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeA

llm = ChatGoogleGenerativeAI(
    model="models/gemini-flash-latest",
    temperature=0.4
)
# Out:
# The capital of France is **Paris**.

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv

load_dotenv()
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025

# %%
response = llm.invoke("What is the genes?")
print(response.text)
# Out:
# This is a great question! It seems like you are asking about the **gene** (singular) or **genes** (plural).
#
# Here is a detailed explanation of what a gene is, what it does, and why it is so important:
#
# ---
#
# ## What is a Gene?
#
# A **gene** is the fundamental unit of heredity in living organisms. Think of it as a specific, functional segment of **DNA** (Deoxyribonucleic Acid).
#
# ### 1. The Analogy: The Instruction Manual
#
# The easiest way to understand genes is to think of them as **recipes** or **blueprints** in a massive instruction manual.
#
# *   **The Instruction Manual:** This is the entire set of DNA in an organism, called the **genome**.
# *   **The Recipes/Blueprints (Genes):** Each gene contains the specific instructions needed to build one particular product, usually a **protein**.
#
# ### 2. Location and Structure
#
# *   **Where are they?** Genes are located on structures called **chromosomes**, which are found inside the nucleus of almost every cell in your body.
# *   **What are they made of?** Genes are made up of a sequence of chemical building blocks called **nucleotides**. In DNA, there are four types of nucleotides: A, T, C, and G (Adenine, Thymine, Cytosine, and Guanine).
# *   **The Code:** The specific order of these A, T, C, and G letters forms a code that determines the structure of the protein it will create.
#
# ---
#
# ## What Do Genes Do? (The Function)
#
# The primary function of a gene is to provide the instructions for making **proteins**. Proteins are the workhorses of the cell—they do almost everything.
#
# ### 1. Building and Operating the Body
#
# Genes control virtually every characteristic and function of an organism:
#
# | Function | Example |
# | :--- | :--- |
# | **Structure** | Genes instruct cells to make **collagen**, which forms your skin, bones, and tendons. |
# | **Movement** | Genes create proteins like **actin** and **myosin** that allow your muscles to contract. |
# | **Catalysis** | Genes produce **enzymes**, which are proteins that speed up chemical reactions (like digesting food). |
# | **Transport** | Genes create **hemoglobin**, the protein that carries oxygen in your blood. |
# | **Identity** | Genes determine your **blood type**, **eye color**, and general body plan. |
#
# ### 2. Gene Expression (The Process)
#
# The process of turning the instructions in a gene into a functional product (usually a protein) is called **gene expression**. It happens in two main steps:
#
# 1.  **Transcription:** The DNA code of the gene is copied into a temporary messenger molecule called **mRNA** (messenger RNA).
# 2.  **Translation:** The mRNA travels to a structure called the ribosome, where the code is read, and amino acids are linked together in the correct order to build the specific **protein**.
#
# ---
#
# ## Genes, Heredity, and Variation
#
# ### 1. Heredity
#
# Genes are the reason offspring resemble their parents. When organisms reproduce, they pass copies of their genes to the next generation.
#
# *   Humans inherit **half** of their genes from their mother and **half** from their father.
# *   This combination of genes determines the unique traits of the individual.
#
# ### 2. Alleles and Variation
#
# For most genes, there are different versions. These versions are called **alleles**.
#
# *   **Example:** The gene for eye color has different alleles. One allele might code for blue eyes, and another might code for brown eyes.
# *   The combination of alleles you inherit determines the final trait you express. This variation in alleles is what makes every individual unique (except for identical twins).
#
# ### 3. Mutations
#
# Sometimes, errors occur when DNA is copied, leading to a change in the nucleotide sequence of a gene. This is called a **mutation**.
#
# *   **Effect:** A mutation can change the instructions, potentially leading to a protein that doesn't work correctly.
# *   **Impact:** While many mutations are harmless, some can cause genetic disorders (like cystic fibrosis or sickle cell anemia) or contribute to diseases like cancer.
#
# ---
#
# ## Summary
#
# In short:
#
# A **gene** is a segment of **DNA** that holds the specific instructions (the code) for building a particular **protein**. Genes are the fundamental units of heredity, determining all the traits and functions of a living organism.

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant."),
        ("human", "{input}"),
    ]
)

print(prompt)
# Out:
# input_variables=['input'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]

# %%
chain = prompt | llm| output_parser

# %%
def test_google_genai(msg):
    response = llm.invoke(msg)

    print(response)

# %%
test_google_genai("what is the generative ai?")
# Out:
# content='That\'s a fantastic and very timely question. **Generative AI** is one of the most exciting and rapidly evolving fields in technology today.\n\nHere is a comprehensive breakdown of what Generative AI is, how it works, and why it\'s important.\n\n---\n\n## 1. The Core Definition of Generative AI\n\n**Generative AI (GenAI)** is a category of artificial intelligence models that are designed to **create new, original content** rather than simply analyzing or classifying existing data.\n\n*   **Traditional AI (Discriminative AI):** Answers questions like: "Is this a cat or a dog?" (Classification) or "What is the price of this house?" (Prediction).\n*   **Generative AI:** Answers questions like: "Draw me a picture of a cat wearing a spacesuit," or "Write a poem about the future of space travel." (Creation).\n\nIn short, **Generative AI is AI that creates.**\n\n---\n\n## 2. What Can Generative AI Create?\n\nGenerative AI models are trained on massive datasets of existing human-created content (text, images, code, music, etc.) and learn the underlying patterns and structures of that data. They can then use these learned patterns to produce novel outputs.\n\nThe primary types of content GenAI creates include:\n\n| Output Type | Examples of Models/Tools | What it Creates |\n| :--- | :--- | :--- |\n| **Text** | ChatGPT, Google Gemini, Microsoft Copilot, Claude | Articles, emails, summaries, code, scripts, novels, poems, translations. |\n| **Images/Art** | Midjourney, DALL-E, Stable Diffusion | Photorealistic images, abstract art, logos, concept designs, and digital paintings from text descriptions (prompts). |\n| **Code** | GitHub Copilot, Amazon CodeWhisperer | Programming code snippets, entire functions, debugging suggestions, and documentation. |\n| **Audio/Music** | Google Lyria, AIVA, Jukebox | Original musical compositions, sound effects, synthetic voiceovers, and realistic speech synthesis. |\n| **Video/3D** | Runway Gen-2, Pika Labs, Luma AI | Short video clips, 3D models, and animation sequences based on text or image inputs. |\n\n---\n\n## 3. How Generative AI Works (The Training Process)\n\nGenerative AI relies on complex machine learning architectures, primarily **Neural Networks**, and specifically a type called **Large Models** (like Large Language Models, or LLMs).\n\n### A. Training (Learning the World)\n\n1.  **Massive Dataset:** The model is fed an enormous amount of data (e.g., the entire public internet, billions of images, or millions of books).\n2.  **Pattern Recognition:** The model learns the statistical relationships between the data points. For text, it learns which words typically follow other words. For images, it learns how colors, shapes, and textures combine.\n3.  **Parameter Adjustment:** The model adjusts its internal "parameters" (billions or trillions of them) to accurately represent these patterns.\n\n### B. Generation (Creating New Content)\n\n1.  **The Prompt:** A user provides an input, known as a "prompt" (e.g., "Write a 500-word blog post about electric cars").\n2.  **Prediction/Sampling:** The model doesn\'t copy-paste. Instead, it uses its learned patterns to predict the most statistically probable next element (word, pixel, musical note) that should follow the input.\n3.  **Iteration:** It repeats this prediction process thousands of times, building the output piece by piece until the content is complete. The result is content that is statistically similar to its training data but is entirely new.\n\n---\n\n## 4. Key Types of Generative Models\n\nWhile there are many specific architectures, the most common and powerful types of Generative AI models are:\n\n### A. Large Language Models (LLMs)\n*   **Focus:** Text and code.\n*   **Mechanism:** Based on the **Transformer** architecture (the "T" in GPT, which stands for Generative Pre-trained Transformer). They excel at understanding context and generating coherent, human-like language.\n*   **Examples:** GPT-4, Gemini, Llama.\n\n### B. D ...
