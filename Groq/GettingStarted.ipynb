# %%
import os
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="llama-3.1-8b-instant", temperature=0.7,groq_api_key=os.getenv("GROQ_API_KEY"))

model
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x0000025DAA72D0F0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000025DAE82F0A0>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage,SystemMessage
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="What is the capital of France?"),
]

result=model.invoke(messages)

# %%
result
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 48, 'total_tokens': 56, 'completion_time': 0.007336622, 'completion_tokens_details': None, 'prompt_time': 0.002240215, 'prompt_tokens_details': None, 'queue_time': 0.044787741, 'total_time': 0.009576837}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c4f97-2853-7d93-8ed7-80aa038cd769-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 48, 'output_tokens': 8, 'total_tokens': 56})

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()
parser.invoke(result)
# Out:
# 'The capital of France is Paris.'

# %%
chain =model | parser
chain.invoke(messages)
# Out:
# 'The capital of France is Paris.'

# %%
from langchain_core.prompts import ChatPromptTemplate

generic_prompt = ChatPromptTemplate.from_messages(
    [
       ("system", "You are a helpful assistant."),
       ("human", "{text}")
    ]
)

# %%
chain =generic_prompt | model | parser
chain.invoke({"text":"what is Artificial Intelligence?"})
# Out:
# 'Artificial Intelligence (AI) is the simulation of human intelligence in machines that are programmed to think and learn like humans. The term can refer to any machine that exhibits traits associated with a human mind such as:\n\n1. **Learning**: AI systems can improve their performance on a task over time, often by learning from data or experiences.\n2. **Problem-solving**: AI systems can analyze complex data, identify patterns, and make decisions based on that analysis.\n3. **Reasoning**: AI systems can draw conclusions from data and make predictions based on that data.\n4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, or text.\n\nAI systems can be categorized into two main types:\n\n1. **Narrow or Weak AI**: These systems are designed to perform a specific task, such as:\n\t* Virtual assistants (e.g., Siri, Alexa)\n\t* Image recognition systems\n\t* Chatbots\n2. **General or Strong AI**: These systems are designed to perform any intellectual task that a human can, such as:\n\t* Self-awareness\n\t* Consciousness\n\t* Emotional intelligence\n\nAI can be applied in various industries, including:\n\n1. **Healthcare**: AI-powered diagnosis, personalized medicine, and medical research.\n2. **Finance**: AI-powered trading, risk management, and customer service.\n3. **Transportation**: AI-powered autonomous vehicles, route optimization, and traffic management.\n4. **Education**: AI-powered adaptive learning, personalized education, and student assessment.\n\nAI has the potential to bring significant benefits, such as:\n\n1. **Increased efficiency**: AI can automate repetitive and mundane tasks.\n2. **Improved accuracy**: AI can analyze large amounts of data and make predictions with high accuracy.\n3. **Enhanced decision-making**: AI can provide insights and recommendations based on data analysis.\n\nHowever, AI also raises concerns about:\n\n1. **Job displacement**: AI may automate jobs, potentially displacing human workers.\n2. **Bias and fairness**: AI systems can perpetuate biases and discrimination if trained on biased data.\n3. **Security**: AI systems can be vulnerable to cyber attacks and data breaches.\n\nOverall, AI is a rapidly evolving field that has the potential to transform industries and improve lives, but it also requires careful consideration of its social and economic implications.'
